# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# !pip install Pillow==9.0.0
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 MB 20.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for Pillow: filename=Pillow-9.0.0-cp311-cp311-linux_x86_64.whl size=1177636 sha256=70744de5e7139b76a65c3f7ed28425a37c85ec7c11d431f9ef73a8395dbb4181
#   Stored in directory: /root/.cache/pip/wheels/0c/83/93/7ecd5a526f27268c0d6d47c5906dc7d368748226e281caf158
# Successfully built Pillow
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 11.2.1
#     Uninstalling pillow-11.2.1:
#       Successfully uninstalled pillow-11.2.1
# ...

# %%
from PIL import Image
import pytesseract

text=pytesseract.image_to_string(Image.open('/content/IBM.png'))

print(text)
# Out:
# In recognition of the commitment to achieve
# professional excellence
#
# Bhavya Bhaskar Arora
#
# Has successfully satisfied the requirements for:
#
# Cybersecurity Fundamentals
#
# Issued on: Jun 24, 2025
# Issued by: IBM SkillsBuild
#
# Verify: https://www.credly.com/badges/26f1027a-adc4-4489-8432-36df1652ceee
